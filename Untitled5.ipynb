# %% [markdown]
# <a href="https://colab.research.google.com/github/vestarhector/AI-Course-2026/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.DataFrame({
    "ID" : ["100","101","102","103","104"],
    "Gender" : ["Female","F","Male","M","Nan"],
    "Weight" : ["56","60","100","45","90"],
    "Age": ["25","40","50","70","90"]
}, index = ["Teresa","Kaja","Thato","James","Carlos"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, Teresa to Carlos
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      5 non-null      object
#  1   Gender  5 non-null      object
#  2   Weight  5 non-null      object
#  3   Age     5 non-null      object
# dtypes: object(4)
# memory usage: 200.0+ bytes

# %%
df.shape
# Out:
# (5, 4)

# %%
df.head()
# Out:
#          ID  Gender Weight Age
# Teresa  100  Female     56  25
# Kaja    101       F     60  40
# Thato   102    Male    100  50
# James   103       M     45  70
# Carlos  104     Nan     90  90

# %%
#i want the id to be an integer
df["ID"]=df["ID"].astype(int)

# %%
df.loc['Kaja']
# Out:
# ID        101
# Gender      F
# Weight     60
# Age        40
# Name: Kaja, dtype: object

# %%
#to check if data is converted
df["ID"].sum()
# Out:
# np.int64(510)

# %%
#converting weight to float
df["Weight"]=df["Weight"].astype(float)

# %%
df["Age"]=df["Age"].astype(int)

# %%
df["Age"].dtype
# Out:
# dtype('int64')

# %%
#check if wieght is converted to float
df["Weight"].dtype
# Out:
# dtype('float64')

# %%
#to group weight by gender
df.groupby('Gender')['Weight'].sum()
# Out:
# Gender
# F          60.0
# Female     56.0
# M          45.0
# Male      100.0
# Nan        90.0
# Name: Weight, dtype: float64

# %%
df['Age'].groupby(df['Gender']).mean()
# Out:
# Gender
# F         40.0
# Female    25.0
# M         70.0
# Male      50.0
# Nan       90.0
# Name: Age, dtype: float64

# %%
df.plot()
# Out:
# <Axes: >

# %%
from google.colab import files
uploaded = files.upload()

import io
data = pd.read_csv(io.BytesIO(uploaded['sa_healthcare_messy_v2.csv']))
# Out:
#      <input type="file" id="files-0dabf58c-b66d-4754-9986-4590981a83c2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0dabf58c-b66d-4754-9986-4590981a83c2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv('sa_healthcare_messy_v2 (2).csv')

# %%
data.shape
# Out:
# (1010, 7)

# %%
data.head(10)
# Out:
#      ID  Age  Gender        BMI       Province   Smoker        Annual_Spent
# 0  5000   45       U  42.701279        Gauteng       No        CORRUPT_DATA
# 1  5001  150       M  58.177369        gauteng      NaN        CORRUPT_DATA
# 2  5002   25       F  48.736658        Gauteng      NaN        CORRUPT_DATA
# 3  5003   22       M  53.537076        Limpopo      Yes        CORRUPT_DATA
# 4  5004   22    male  24.699273  KwaZulu-Natal      Yes        CORRUPT_DATA
# 5  5005   22       U  36.530357        Gauteng      NaN        CORRUPT_DATA
# 6  5006   30       F  28.959672        W. Cape       No  62663.721431705664
# 7  5007   30    male  30.193432        Gauteng  Unknown  48499.411469087114
# 8  5008   -5    male  10.865355        Limpopo      NaN   45722.24632615133
# 9  5009   22  FEMALE  17.589134        W. Cape      NaN  13918.745344079955

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1010 entries, 0 to 1009
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            1010 non-null   int64
#  1   Age           1010 non-null   int64
#  2   Gender        1010 non-null   object
#  3   BMI           934 non-null    float64
#  4   Province      1010 non-null   object
#  5   Smoker        764 non-null    object
#  6   Annual_Spent  1010 non-null   object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 55.4+ KB

# %%
data['Gender'] = data['Gender'].replace({'U':'Unkown'})

# %%
data['Gender']
# Out:
# 0       Unkown
# 1            M
# 2            F
# 3            M
# 4         male
#          ...
# 1005      male
# 1006         M
# 1007      male
# 1008    Unkown
# 1009    FEMALE
# Name: Gender, Length: 1010, dtype: object

# %%
pv_data= data['Province']

# %%
prov_map = {'gauteng':'Gauteng','W. Cape':'Western Cape','KZN':'KwaZulu-Natal'}

# %%
data['Province'] = data['Province'].replace(prov_map)

# %%
#df1 = data[['Province'], ['BMI']]
df1 = data[['Province', 'BMI']]

# %%
df1.head(20)
# Out:
#          Province        BMI
# 0         Gauteng  42.701279
# 1         Gauteng  58.177369
# 2         Gauteng  48.736658
# 3         Limpopo  53.537076
# 4   KwaZulu-Natal  24.699273
# 5         Gauteng  36.530357
# 6    Western Cape  28.959672
# 7         Gauteng  30.193432
# 8         Limpopo  10.865355
# 9    Western Cape  17.589134
# 10  KwaZulu-Natal  31.090748
# 11        Gauteng  31.410023
# 12     Free State  18.116784
# 13        Gauteng  31.126888
# 14   Western Cape  50.149201
# 15        Limpopo  34.994447
# 16  KwaZulu-Natal  55.063202
# 17        Gauteng  29.355903
# 18        Gauteng        NaN
# 19   Western Cape  50.432031

# %%
data[:3]
# Out:
#      ID  Age  Gender        BMI Province Smoker  Annual_Spent
# 0  5000   45  Unkown  42.701279  Gauteng     No  CORRUPT_DATA
# 1  5001  150       M  58.177369  Gauteng    NaN  CORRUPT_DATA
# 2  5002   25       F  48.736658  Gauteng    NaN  CORRUPT_DATA

# %%
data.index
# Out:
# RangeIndex(start=0, stop=1010, step=1)

# %%
data['Annual_Spent'] = pd.to_numeric(data['Annual_Spent'],errors='coerce' )

# %%
data.head()
# Out:
#      ID  Age  Gender        BMI       Province Smoker  Annual_Spent
# 0  5000   45  Unkown  42.701279        Gauteng     No           NaN
# 1  5001  150       M  58.177369        Gauteng    NaN           NaN
# 2  5002   25       F  48.736658        Gauteng    NaN           NaN
# 3  5003   22       M  53.537076        Limpopo    Yes           NaN
# 4  5004   22    male  24.699273  KwaZulu-Natal    Yes           NaN

# %%
data.shape
# Out:
# (1010, 7)

# %%
#all object data must be converted to proper data types
#checking data types
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1010 entries, 0 to 1009
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            1010 non-null   int64
#  1   Age           1010 non-null   int64
#  2   Gender        1010 non-null   object
#  3   BMI           934 non-null    float64
#  4   Province      1010 non-null   object
#  5   Smoker        764 non-null    object
#  6   Annual_Spent  1004 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 55.4+ KB

# %%
data = data[(data['Age'] > 0) & (data['Age'] < 100)]

# %%
data.shape
# Out:
# (685, 7)
